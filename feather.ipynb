# %%
import feather
import pandas as pd
import numpy as np

import os

np.random.seed = 2021
df_size = 10000000

df = pd.DataFrame({
    'a': np.random.rand(df_size),
    'b': np.random.rand(df_size),
    'c': np.random.rand(df_size),
    'd': np.random.rand(df_size),
    'e': np.random.rand(df_size)
    })

# %%
df.to_feather('data.feather')
df
# Out:
#                 a         b         c         d         e
# 0        0.077934  0.720626  0.838391  0.478373  0.445147
# 1        0.042840  0.731030  0.834244  0.510513  0.244482
# 2        0.429953  0.287673  0.667825  0.862836  0.010011
# 3        0.432189  0.650207  0.929237  0.963033  0.669403
# 4        0.614473  0.241581  0.410426  0.007846  0.129413
# ...           ...       ...       ...       ...       ...
# 9999995  0.152087  0.349808  0.739653  0.830169  0.354299
# 9999996  0.500648  0.049605  0.542606  0.104870  0.417472
# 9999997  0.552578  0.556619  0.017628  0.668866  0.713346
# 9999998  0.983280  0.999219  0.582125  0.391654  0.714830
# 9999999  0.308218  0.879747  0.020771  0.821667  0.655862
#
# [10000000 rows x 5 columns]

# %%
data = feather.read_dataframe('data.feather')
data
# Out:
#                 a         b         c         d         e
# 0        0.077934  0.720626  0.838391  0.478373  0.445147
# 1        0.042840  0.731030  0.834244  0.510513  0.244482
# 2        0.429953  0.287673  0.667825  0.862836  0.010011
# 3        0.432189  0.650207  0.929237  0.963033  0.669403
# 4        0.614473  0.241581  0.410426  0.007846  0.129413
# ...           ...       ...       ...       ...       ...
# 9999995  0.152087  0.349808  0.739653  0.830169  0.354299
# 9999996  0.500648  0.049605  0.542606  0.104870  0.417472
# 9999997  0.552578  0.556619  0.017628  0.668866  0.713346
# 9999998  0.983280  0.999219  0.582125  0.391654  0.714830
# 9999999  0.308218  0.879747  0.020771  0.821667  0.655862
#
# [10000000 rows x 5 columns]
